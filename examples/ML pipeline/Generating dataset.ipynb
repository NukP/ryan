# %%
from ryan.ml_pipeline.dataset import main
from ryan.ml_pipeline.dataset import custom_columns as cc

# %%
dataset = main.gen_dataset(
        gc_excel_dir = 'example data files',
        conditions_fln=[],
        conditions_idx=[],
        ls_input_extract=['time', 'Eapp [V]'],
        ls_input_gen= [
],
        ls_output_extract=[],
        ls_output_gen=[cc.delta_Eapp_fluctuation],
        num_cpu=1,
        pre_gen_electro_df=True,
        #export_df=f'dataset_macbookair.xlsx'

)

dataset
